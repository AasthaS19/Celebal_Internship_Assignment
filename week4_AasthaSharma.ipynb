# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed for **students and beginners** to learn:
# - How image classification works
# - Why **CNN performs better than ANN**
# - How architecture impacts performance
# - How training strategies improve results
#
# 🎯 **Learning Goal:** Understand the complete DL pipeline by **reading the markdown + running the ready code**.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies (dropout, batch norm, augmentation)
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
# This helps students understand **why CNN is better for images**.

# %%
ann_model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# c:\Users\AASTHA\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.2746 - loss: 1.9849 - val_accuracy: 0.3288 - val_loss: 1.8635
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3122 - loss: 1.8720 - val_accuracy: 0.3574 - val_loss: 1.7989
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.3293 - loss: 1.8299 - val_accuracy: 0.3686 - val_loss: 1.7651
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.3442 - loss: 1.7956 - val_accuracy: 0.3850 - val_loss: 1.7271
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.3572 - loss: 1.7642 - val_accuracy: 0.3856 - val_loss: 1.7260
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.3631 - loss: 1.7475 - val_accuracy: 0.3958 - val_loss: 1.7186
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.3735 - loss: 1.7256 - val_accuracy: 0.4048 - val_loss: 1.6936
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.3793 - loss: 1.7118 - val_accuracy: 0.4154 - val_loss: 1.6604
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.3826 - loss: 1.7011 - val_accuracy: 0.4270 - val_loss: 1.6494
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3860 - loss: 1.6897 - val_accuracy: 0.4328 - val_loss: 1.6460

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4322 - loss: 1.6322
# ANN Test Accuracy: 0.43220001459121704

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# This is why CNN performs much better for image tasks.

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history = cnn_model.fit(
    x_train_norm, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# c:\Users\AASTHA\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 51s 63ms/step - accuracy: 0.4691 - loss: 1.4928 - val_accuracy: 0.4726 - val_loss: 1.4788
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.6017 - loss: 1.1326 - val_accuracy: 0.5974 - val_loss: 1.1661
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 42s 60ms/step - accuracy: 0.6653 - loss: 0.9572 - val_accuracy: 0.6108 - val_loss: 1.1697
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 45s 64ms/step - accuracy: 0.7103 - loss: 0.8313 - val_accuracy: 0.6924 - val_loss: 0.9094
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 43s 61ms/step - accuracy: 0.7382 - loss: 0.7412 - val_accuracy: 0.6926 - val_loss: 0.8827
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 46s 65ms/step - accuracy: 0.7674 - loss: 0.6571 - val_accuracy: 0.6982 - val_loss: 0.8954
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 46s 65ms/step - accuracy: 0.7917 - loss: 0.5876 - val_accuracy: 0.7062 - val_loss: 0.9258
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 80s 63ms/step - accuracy: 0.8120 - loss: 0.5260 - val_accuracy: 0.6974 - val_loss: 0.9499
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 62ms/step - accuracy: 0.8272 - loss: 0.4812 - val_accuracy: 0.7042 - val_loss: 1.0492
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 45s 63ms/step - accuracy: 0.8430 - loss: 0.4382 - val_accuracy: 0.7260 - val_loss: 0.9174

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7127 - loss: 0.9725
# CNN Test Accuracy: 0.7127000093460083

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

aug_cnn_model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

aug_cnn_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# Suggested optional run:
# aug_history = aug_cnn_model.fit(x_train_norm, y_train, epochs=10, validation_split=0.1)

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": ["ANN", "CNN"],
    "Test Accuracy": [ann_test_acc, cnn_test_acc]
})
comparison
# Out:
#   Model  Test Accuracy
# 0   ANN         0.4322
# 1   CNN         0.7127

# %% [markdown]
# # 🎓 Student Learning Tasks
# Try these tasks after understanding the notebook:
#
# ### ✅ Beginner Tasks
# 1. Increase ANN layers and observe performance
# 2. Change CNN filters from 32→64→128
# 3. Increase epochs to 20
# 4. Add **EarlyStopping**
# 5. Add **data augmentation training**

# %% [markdown]
# ## 🧪 Task Implementations
# The five beginner tasks below are implemented and run end-to-end, each in its own cell.

# %% [markdown]
# ### ✅ Task 1: Increase ANN layers and observe performance
# We deepen the original 2-hidden-layer ANN into a 4-hidden-layer network and compare test accuracy against the baseline ANN.

# %%
# Task 1: Deeper ANN
deep_ann_model = models.Sequential([
    layers.Dense(1024, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

deep_ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

deep_ann_history = deep_ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)

deep_ann_test_loss, deep_ann_test_acc = deep_ann_model.evaluate(x_test_flat, y_test)
print("Deeper ANN Test Accuracy:", deep_ann_test_acc)
print("Baseline ANN Test Accuracy:", ann_test_acc)
# Out:
# c:\Users\AASTHA\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 50s 66ms/step - accuracy: 0.2444 - loss: 2.0378 - val_accuracy: 0.3232 - val_loss: 1.8725
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 46s 66ms/step - accuracy: 0.3114 - loss: 1.8780 - val_accuracy: 0.3562 - val_loss: 1.7984
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.3282 - loss: 1.8374 - val_accuracy: 0.3538 - val_loss: 1.7908
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 78ms/step - accuracy: 0.3500 - loss: 1.7903 - val_accuracy: 0.3974 - val_loss: 1.7171
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 51s 72ms/step - accuracy: 0.3577 - loss: 1.7689 - val_accuracy: 0.3826 - val_loss: 1.7231
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 49s 69ms/step - accuracy: 0.3684 - loss: 1.7445 - val_accuracy: 0.3918 - val_loss: 1.7197
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 50s 71ms/step - accuracy: 0.3755 - loss: 1.7227 - val_accuracy: 0.4168 - val_loss: 1.6730
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 51s 72ms/step - accuracy: 0.3814 - loss: 1.7082 - val_accuracy: 0.4118 - val_loss: 1.6648
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 48s 69ms/step - accuracy: 0.3804 - loss: 1.7034 - val_accuracy: 0.4108 - val_loss: 1.6930
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 48s 69ms/step - accuracy: 0.3894 - loss: 1.6880 - val_accuracy: 0.4264 - val_loss: 1.6271
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4419 - loss: 1.6068
# Deeper ANN Test Accuracy: 0.44190001487731934
# Baseline ANN Test Accuracy: 0.43220001459121704

# %% [markdown]
# ### ✅ Task 2: Change CNN filters from 32 → 64 → 128
# The `cnn_model` built above already scales filters as 32 → 64 → 128 across its three convolution blocks. The summary below confirms the filter progression layer by layer.

# %%
# Task 2: Confirm the 32 -> 64 -> 128 filter progression in cnn_model
cnn_model.summary()

conv_layers = [l for l in cnn_model.layers if isinstance(l, layers.Conv2D)]
for l in conv_layers:
    print(l.name, "-> filters:", l.filters)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,071,200 (4.09 MB)
#  Trainable params: 357,002 (1.36 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 714,006 (2.72 MB)
# conv2d -> filters: 32
# conv2d_1 -> filters: 64
# conv2d_2 -> filters: 128

# %% [markdown]
# ### ✅ Task 3: Increase epochs to 20
# We retrain a fresh copy of the CNN architecture for 20 epochs instead of 10, to see whether validation accuracy keeps improving with more training time.

# %%
# Task 3: Train the same CNN architecture for 20 epochs
cnn_model_20 = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model_20.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history_20 = cnn_model_20.fit(
    x_train_norm, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64
)

cnn_test_loss_20, cnn_test_acc_20 = cnn_model_20.evaluate(x_test_norm, y_test)
print("CNN (20 epochs) Test Accuracy:", cnn_test_acc_20)
print("CNN (10 epochs) Test Accuracy:", cnn_test_acc)
# Out:
# c:\Users\AASTHA\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.4594 - loss: 1.5046 - val_accuracy: 0.5142 - val_loss: 1.3364
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 43s 61ms/step - accuracy: 0.6072 - loss: 1.1174 - val_accuracy: 0.5984 - val_loss: 1.1363
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.6675 - loss: 0.9521 - val_accuracy: 0.6428 - val_loss: 1.0332
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.7103 - loss: 0.8336 - val_accuracy: 0.6554 - val_loss: 1.0039
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.7432 - loss: 0.7388 - val_accuracy: 0.6648 - val_loss: 0.9942
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.7664 - loss: 0.6689 - val_accuracy: 0.6748 - val_loss: 0.9600
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 62ms/step - accuracy: 0.7920 - loss: 0.5939 - val_accuracy: 0.7004 - val_loss: 0.8680
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 45s 64ms/step - accuracy: 0.8113 - loss: 0.5340 - val_accuracy: 0.7330 - val_loss: 0.7905
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 62ms/step - accuracy: 0.8303 - loss: 0.4757 - val_accuracy: 0.7228 - val_loss: 0.8729
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 63ms/step - accuracy: 0.8450 - loss: 0.4379 - val_accuracy: 0.7406 - val_loss: 0.8751
# Epoch 11/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 45s 64ms/step - accuracy: 0.8577 - loss: 0.3974 - val_accuracy: 0.7224 - val_loss: 0.9111
# Epoch 12/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 63ms/step - accuracy: 0.8708 - loss: 0.3642 - val_accuracy: 0.7356 - val_loss: 0.9566
# Epoch 13/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 62ms/step - accuracy: 0.8768 - loss: 0.3428 - val_accuracy: 0.7468 - val_loss: 0.9320
# Epoch 14/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 43s 62ms/step - accuracy: 0.8880 - loss: 0.3120 - val_accuracy: 0.7188 - val_loss: 1.0777
# Epoch 15/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 45s 63ms/step - accuracy: 0.8938 - loss: 0.2942 - val_accuracy: 0.7318 - val_loss: 1.0151
# Epoch 16/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.9031 - loss: 0.2726 - val_accuracy: 0.7074 - val_loss: 1.2679
# Epoch 17/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.9062 - loss: 0.2601 - val_accuracy: 0.7506 - val_loss: 1.0257
# Epoch 18/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.9116 - loss: 0.2470 - val_accuracy: 0.6886 - val_loss: 1.3907
# Epoch 19/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.9158 - loss: 0.2389 - val_accuracy: 0.7366 - val_loss: 1.1449
# Epoch 20/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.9190 - loss: 0.2226 - val_accuracy: 0.7318 - val_loss: 1.2456
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7162 - loss: 1.3295
# CNN (20 epochs) Test Accuracy: 0.7161999940872192
# CNN (10 epochs) Test Accuracy: 0.7127000093460083

# %% [markdown]
# ### ✅ Task 4: Add EarlyStopping
# We add Keras' `EarlyStopping` callback (monitoring validation loss, with `restore_best_weights=True`) so training halts once the model stops improving, and train for up to 20 epochs.

# %%
# Task 4: EarlyStopping callback
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

cnn_model_es = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model_es.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history_es = cnn_model_es.fit(
    x_train_norm, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stop]
)

cnn_test_loss_es, cnn_test_acc_es = cnn_model_es.evaluate(x_test_norm, y_test)
print("CNN + EarlyStopping Test Accuracy:", cnn_test_acc_es)
print("Stopped at epoch:", len(cnn_history_es.history['loss']), "out of 20")
# Out:
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.4727 - loss: 1.4842 - val_accuracy: 0.5484 - val_loss: 1.2565
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.6058 - loss: 1.1239 - val_accuracy: 0.6398 - val_loss: 1.0356
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.6648 - loss: 0.9576 - val_accuracy: 0.6716 - val_loss: 0.9215
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.7102 - loss: 0.8310 - val_accuracy: 0.6362 - val_loss: 1.1053
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.7426 - loss: 0.7401 - val_accuracy: 0.6952 - val_loss: 0.8935
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.7714 - loss: 0.6521 - val_accuracy: 0.6886 - val_loss: 0.9731
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.7912 - loss: 0.5864 - val_accuracy: 0.7170 - val_loss: 0.8270
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 42s 57ms/step - accuracy: 0.8137 - loss: 0.5239 - val_accuracy: 0.7304 - val_loss: 0.8885
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.8339 - loss: 0.4710 - val_accuracy: 0.7080 - val_loss: 0.9651
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.8473 - loss: 0.4298 - val_accuracy: 0.7176 - val_loss: 0.9115
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7117 - loss: 0.8726
# CNN + EarlyStopping Test Accuracy: 0.7117000222206116
# Stopped at epoch: 10 out of 20

# %% [markdown]
# ### ✅ Task 5: Add data augmentation training
# We now actually run the training for `aug_cnn_model` (previously only defined, not trained), reusing the `EarlyStopping` callback from Task 4.

# %%
# Task 5: Train the augmented CNN model
aug_history = aug_cnn_model.fit(
    x_train_norm, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stop]
)

aug_test_loss, aug_test_acc = aug_cnn_model.evaluate(x_test_norm, y_test)
print("Augmented CNN Test Accuracy:", aug_test_acc)
# Out:
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.3659 - loss: 1.7424 - val_accuracy: 0.4928 - val_loss: 1.4123
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - accuracy: 0.4580 - loss: 1.5022 - val_accuracy: 0.5464 - val_loss: 1.2787
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - accuracy: 0.4930 - loss: 1.4200 - val_accuracy: 0.5310 - val_loss: 1.3111
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4855 - loss: 1.4112
# Augmented CNN Test Accuracy: 0.4855000078678131

# %% [markdown]
# ## 📊 Extended Comparison: All Model Variants
# Validation accuracy curves and final test accuracy for every model built in this notebook, including the baseline ANN/CNN and all five task variants.

# %%
# Extended validation accuracy curve comparison
plt.figure(figsize=(12,6))
plt.plot(ann_history.history['val_accuracy'], label='ANN (baseline)')
plt.plot(cnn_history.history['val_accuracy'], label='CNN (baseline, 10 epochs)')
plt.plot(deep_ann_history.history['val_accuracy'], label='Deeper ANN (Task 1)')
plt.plot(cnn_history_20.history['val_accuracy'], label='CNN (Task 3, 20 epochs)')
plt.plot(cnn_history_es.history['val_accuracy'], label='CNN + EarlyStopping (Task 4)')
plt.plot(aug_history.history['val_accuracy'], label='Augmented CNN (Task 5)')
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy Across All Model Variants")
plt.legend()
plt.show()

# %%
# Extended final comparison table across all model variants
extended_comparison = pd.DataFrame({
    "Model": [
        "ANN (baseline)",
        "CNN (baseline, 10 epochs)",
        "Deeper ANN (Task 1)",
        "CNN (Task 3, 20 epochs)",
        "CNN + EarlyStopping (Task 4)",
        "Augmented CNN (Task 5)"
    ],
    "Test Accuracy": [
        ann_test_acc,
        cnn_test_acc,
        deep_ann_test_acc,
        cnn_test_acc_20,
        cnn_test_acc_es,
        aug_test_acc
    ]
})
extended_comparison
# Out:
#                           Model  Test Accuracy
# 0                ANN (baseline)         0.4322
# 1     CNN (baseline, 10 epochs)         0.7127
# 2           Deeper ANN (Task 1)         0.4419
# 3       CNN (Task 3, 20 epochs)         0.7162
# 4  CNN + EarlyStopping (Task 4)         0.7117
# 5        Augmented CNN (Task 5)         0.4855

# %% [markdown]
# # ✅ Conclusion
# - **ANN works**, but ignores image structure
# - **CNN extracts spatial features**, so it performs significantly better
# - **Training strategies** like dropout, batch norm, and augmentation improve results
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**
